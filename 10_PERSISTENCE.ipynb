# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_ollama import ChatOllama
from langgraph.checkpoint.memory import InMemorySaver

# %%
llm = ChatOllama(model="llama3.2:latest")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):
    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):
    prompt= f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic': 'pizza'}, config = config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.',
#  'explanation': 'The joke relies on wordplay, specifically punning on the multiple meanings of "crusty."\n\n"Crusty" has two distinct uses:\n\n1. In baking, crust refers to the outer layer of dough that forms on top of bread or pizza.\n2. Emotionally, "crusty" is an adjective used to describe someone (or in this case, a pizza) with a gruff or irritable demeanor.\n\nThe punchline "feeling crusty" has a dual meaning:\n\n* It references the literal crust on a pizza.\n* It describes a person\'s emotional state of being irritable or short-tempered.\n\nBy using the word "crusty" in this way, the joke creates an unexpected connection between the pizza\'s physical characteristics and its emotional state, resulting in a humorous play on words.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.', 'explanation': 'The joke relies on wordplay, specifically punning on the multiple meanings of "crusty."\n\n"Crusty" has two distinct uses:\n\n1. In baking, crust refers to the outer layer of dough that forms on top of bread or pizza.\n2. Emotionally, "crusty" is an adjective used to describe someone (or in this case, a pizza) with a gruff or irritable demeanor.\n\nThe punchline "feeling crusty" has a dual meaning:\n\n* It references the literal crust on a pizza.\n* It describes a person\'s emotional state of being irritable or short-tempered.\n\nBy using the word "crusty" in this way, the joke creates an unexpected connection between the pizza\'s physical characteristics and its emotional state, resulting in a humorous play on words.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f157404-37bf-6a8a-8002-106a86396d3a'}}, m
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.', 'explanation': 'The joke relies on wordplay, specifically punning on the multiple meanings of "crusty."\n\n"Crusty" has two distinct uses:\n\n1. In baking, crust refers to the outer layer of dough that forms on top of bread or pizza.\n2. Emotionally, "crusty" is an adjective used to describe someone (or in this case, a pizza) with a gruff or irritable demeanor.\n\nThe punchline "feeling crusty" has a dual meaning:\n\n* It references the literal crust on a pizza.\n* It describes a person\'s emotional state of being irritable or short-tempered.\n\nBy using the word "crusty" in this way, the joke creates an unexpected connection between the pizza\'s physical characteristics and its emotional state, resulting in a humorous play on words.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f157404-37bf-6a8a-8002-106a86396d3a'}}, 
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic': 'pasta'}, config = config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get dressed?\n\nBecause it was feeling a little "drained" and wanted to twirl with its emotions.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.', 'explanation': 'The joke relies on wordplay, specifically punning on the multiple meanings of "crusty."\n\n"Crusty" has two distinct uses:\n\n1. In baking, crust refers to the outer layer of dough that forms on top of bread or pizza.\n2. Emotionally, "crusty" is an adjective used to describe someone (or in this case, a pizza) with a gruff or irritable demeanor.\n\nThe punchline "feeling crusty" has a dual meaning:\n\n* It references the literal crust on a pizza.\n* It describes a person\'s emotional state of being irritable or short-tempered.\n\nBy using the word "crusty" in this way, the joke creates an unexpected connection between the pizza\'s physical characteristics and its emotional state, resulting in a humorous play on words.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f157404-37bf-6a8a-8002-106a86396d3a'}}, m
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get dressed?\n\nBecause it was feeling a little "drained" and wanted to twirl with its emotions.', 'explanation': 'This joke is a play on words, using puns to create humor.\n\nThe setup of the joke asks why the spaghetti refused to get dressed. The answer could be a serious reason, but instead, it takes an unexpected turn.\n\nThe phrase "feeling a little drained" has a double meaning here. In one sense, it means feeling emotionally exhausted or depleted. However, it also references the fact that spaghetti is a long, thin pasta that can become limp and lifeless when exposed to water (i.e., being "drained" of its moisture).\n\nThe punchline "wants to twirl with its emotions" takes this phrase further by incorporating another aspect of spaghetti culture - the act of twirling around on one\'s fork while eating. In this context, "twirling" has a literal meaning related to the physical action of eating spaghe
# ...

# %% [markdown]
# #### Time Travel
#
# # help to debug the program easily

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f157402-f767-69b8-8001-ea71f64776fc"}})
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f157402-f767-69b8-8001-ea71f64776fc'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-05-24T07:14:21.101304+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1573ff-5012-6800-8000-2f474eddfc32'}}, tasks=(PregelTask(id='a5ad8840-9f5c-c0c4-ca67-c44c7c897a46', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke relies on wordplay, specifically punning on the multiple meanings of "crusty."\n\n"Crusty" has two distinct uses:\n\n1. In baking, crust refers to the outer layer of dough that forms on top of bread or pizza.\n2. Emotionally, "crusty" is an adjective used to describe someone (or in this case, a pizza) 
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f157402-f767-69b8-8001-ea71f64776fc"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling crusty.', 'explanation': 'A classic pun!\n\nThe joke relies on a play on words, where "crusty" has a double meaning.\n\nOn one hand, "crusty" can refer to a type of exterior layer or crust that forms on bread when it\'s baked, like pizza dough. In this sense, the phrase "feeling crusty" is an idiomatic expression used to describe someone who\'s grumpy or short-tempered, like being in a bad mood.\n\nOn the other hand, "crusty" is also a physical characteristic of a crust on pizza, which is typically the outer layer of the dough. In this context, the phrase "feeling crusty" sounds like a literal description of a pizza having a rough or gruff exterior.\n\nThe humor in the joke comes from the unexpected twist on words, where the common expression "feeling crusty" is applied to a food item (pizza) rather than a person. It\'s a lighthearted and silly pun that pokes fun at the idea o
# ...

# %% [markdown]
# ## Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f1573ff-5012-6800-8000-2f474eddfc32", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f157423-3421-6f63-8001-cfed17e74e62'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f157423-3421-6f63-8001-cfed17e74e62'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-05-24T07:28:46.462550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1573ff-5012-6800-8000-2f474eddfc32'}}, tasks=(PregelTask(id='afb1bcf3-c20e-ae8f-6864-59e9065e0ec1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f157423-3421-6f63-8001-cfed17e74e62"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "fried" and had a lot of "cracked" emotions!',
#  'explanation': 'The joke is a play on words, using the multiple meanings of the word "fried".\n\nIn this context, a samosa is a type of Indian savory pastry that is often deep-fried. So, the punchline "feeling a little fried" is a pun on the fact that the samosa itself is fried.\n\nHowever, the phrase "feeling fried" is also an idiomatic expression that means feeling stressed or overwhelmed. This is what\'s referred to as a "cracked emotion".\n\nSo, the joke is saying that the samosa (a food item) is going to therapy because it\'s having emotional issues ("cracked emotions") and is feeling stressed out ("fried"). The humor comes from the unexpected twist on the common phrase "feeling fried" and the clever connection between the food and its emotional state.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "fried" and had a lot of "cracked" emotions!', 'explanation': 'The joke is a play on words, using the multiple meanings of the word "fried".\n\nIn this context, a samosa is a type of Indian savory pastry that is often deep-fried. So, the punchline "feeling a little fried" is a pun on the fact that the samosa itself is fried.\n\nHowever, the phrase "feeling fried" is also an idiomatic expression that means feeling stressed or overwhelmed. This is what\'s referred to as a "cracked emotion".\n\nSo, the joke is saying that the samosa (a food item) is going to therapy because it\'s having emotional issues ("cracked emotions") and is feeling stressed out ("fried"). The humor comes from the unexpected twist on the common phrase "feeling fried" and the clever connection between the food and its emotional state.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpo
# ...

# %% [markdown]
# ## Fault Tolerance
